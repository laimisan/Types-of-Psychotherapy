# %% [markdown]
# # UKCP Scrape Part 1: Profile Links

# %%
from bs4 import BeautifulSoup as bs # HTML and XML parsing
import requests # making HTTP requests
from lxml import etree # xml data parsing
import pandas as pd # data analytics package
import numpy as np # mathematics
import re # regular expressions

# %%
# Creating an empty dictionary that I will add profile links to
profiles = {}

# %% [markdown]
# UKCP website is using Ajax and is a little trickier to scrape compared to BACP with simple HTML. I will have to provide headers in my request and, most importantly, payload, which in this case contains search parameters aiming to get the maximum results.
# One of these parameters is Page Number, and I will use .format to iterate through them all.

# %%
# Header information
headers = {
"authority": 'www.psychotherapy.org.uk',
"method": 'POST',
"path": '/umbraco/Surface/SearchSurface/Search',
"scheme": 'https',
"accept": '*/*',
"accept-encoding": "gzip, deflate, br",
"content-type": 'application/x-www-form-urlencoded; charset=UTF-8',
"origin": 'https://www.psychotherapy.org.uk',
"referer": 'https://www.psychotherapy.org.uk/find-a-therapist/?Distance=30&LocationSearchOutsideUK=true',
"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36",
"x-requested-with": "XMLHttpRequest",
"cookie": "_gcl_au=1.1.1587263335.1663537845; _ga=GA1.3.1419321980.1663537845; _hjSessionUser_2575114=eyJpZCI6IjYxMjQ0YThkLWQ3Y2YtNWE4OC05NTQ2LTc4YzRiMjliZjQxMCIsImNyZWF0ZWQiOjE2NjM1Mzc4NDUyOTIsImV4aXN0aW5nIjp0cnVlfQ==; _gid=GA1.3.810337034.1666535138; TOrderSeed=-636850756; _hjAbsoluteSessionInProgress=0; _gat_gtag_UA_20343789_1=1; _hjIncludedInSessionSample=0; _hjSession_2575114=eyJpZCI6IjY2NWM1NjZlLWY1NzctNDE2ZS1hYjYxLTBkNmY4NDgyNmQzYyIsImNyZWF0ZWQiOjE2NjY3MTE0MTk0NDEsImluU2FtcGxlIjpmYWxzZX0="
}

# A function that takes in website url, retrieves embedded links, and adds them to the dictionary
def scraper(url):
    source = requests.post(url, json=payload, headers=headers).text
    soup = bs(source, 'lxml')
    
    for link in soup.find_all("a", class_="light-anchor"): # iterate throught blocks of code that hold therapists' information
        name = link.find("h2").string # grab the name for my dictionary's keys
        url=link.get("href", "") # getting links for my dictionary's values
        profiles[name] = url

# %%
first_url = "https://www.psychotherapy.org.uk/umbraco/Surface/SearchSurface/Search"

# %%
# A loop that will iterate through pages in the website (using .format on payload string), and add profile info to the ductionary
for page in range(1, 646): # Website shows max number of profiles to be 7741 and 12 per page, so I'll go through 646 pages
    
    # Payload containing search parameters
    payload = "HelpWith=&InPerson=false&Remote=false&Location=&Pager.CurrentPage={}&Pager.PageSize=12&KeywordFilter=&Distance=10&LocationSearchOutsideUK=false&OnlyProfilesWithPhotos=false&OnlyWheelchairAccessible=false&OrderSeed=-636850756&X-Requested-With=XMLHttpRequest".format(page)
    # Keeping track of the progress
    if page in range(1, 646, 10):
        print(page)
        
    # Calling the scraper function defined earlier 
    try:
        scraper(first_url)
    except:
        pass
# Out:
# 1
# 11
# 21
# 31
# 41
# 51
# 61
# 71
# 81
# 91
# 101
# 111
# 121
# 131
# 141
# 151
# 161
# 171
# 181
# 191
# 201
# 211
# 221
# 231
# 241
# 251
# 261
# 271
# 281
# 291
# 301
# 311
# 321
# 331
# 341
# 351
# 361
# 371
# 381
# 391
# 401
# 411
# 421
# 431
# 441
# 451
# 461
# 471
# 481
# 491
# 501
# 511
# 521
# 531
# 541
# 551
# 561
# 571
# 581
# 591
# 601
# 611
# 621
# 631
# 641

# %%
# Creating dataframe from the dictionary
profiles_df = pd.DataFrame.from_dict(profiles, orient="index", columns=['link'])
profiles_df
# Out:
#                                                      link
# Naomi Landau            /therapist/naomi-landau-iai1paas/
# Siobhan Tinker        /therapist/siobhan-tinker-iaixxaa0/
# Rehma Said                /therapist/rehma-said-cnvcuaal/
# Yvonne Rose              /therapist/yvonne-rose-iaih5aak/
# Suzanna Brown          /therapist/suzanna-brown-iai1oaas/
# ...                                                   ...
# Stella Ridley          /therapist/stella-ridley-iajjaaa0/
# Lisa Tedeschini      /therapist/lisa-tedeschini-iai1xaac/
# Claire Barber          /therapist/claire-barber-nrblzaaa/
# Catherine Collins  /therapist/catherine-collins-dgfnqqaz/
# Clare Cribb              /therapist/clare-cribb-yuxczaaf/
#
# [7699 rows x 1 columns]

# %%
# Adding UKCP url to the begining of the link
profiles_df = profiles_df.apply(lambda x: "https://www.psychotherapy.org.uk/"+x)

# %%
# Saving to csv
profiles_df.to_csv('ukcp_links.csv')

# %% [markdown]
# # UKCP Part 2: Scraping the profile data

# %%
## Reading in the file
# profiles_df = pd.read_csv('ukcp_links.csv')
# profiles_df.drop(columns='Unnamed: 0', inplace=True)

# %%
therapist_data = [] # an empty list that I will add dictionaries of therapist data to

# %%
# Creating a function for retrieving relevant headers and info from therapists' profiles

def profile_scrape(url):
    
    info_dict = {} # an empty dictionary for separate sections of the profiles

    page = requests.get(url).text # requesting url
    soup2 = bs(page, 'lxml') # creating a soup object and parsing
    
    try:
        info_dict['name'] = soup2.h1.text # locating header with the name and adding value to the dictionary
    except:
        info_dict['name'] = None
    try:
        info_dict['address'] = soup2.find('span', class_='profile-intro profile-intro-locations').text # adding address
    except:
        info_dict['address'] = None
    try:
        main_body = soup2.find('div', id='AboutMe') # separating main body section
        for section in main_body.find_all('section'):
            # if a section has a paragraph of text, I will grab the header as dictionary key and text as value
            if section.find('p') is not None:
                info_dict[section.h2.text] = section.p.text
            else:
                if section.find('ul') is not None: # otherwise grabbing items from other sections (unordered list)
                    # here I clean up value a bit by creating a list, filtering out none values, and joining it back to a string
                    info_dict[section.h2.text] = ', '.join(list(filter(None, section.ul.text.split('\n'))))
    except:
        pass
                
    therapist_data.append(info_dict) # adding dictionary of data to the list

# %%
# Iterating through the links and scraping profile data
for link in profiles_df['link']:
    profile_scrape(link)
    if len(therapist_data) in range(1, 7741, 100): # tracking the progress
        print(len(therapist_data))
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1001
# 1101
# 1201
# 1301
# 1401
# 1501
# 1601
# 1701
# 1801
# 1901
# 2001
# 2101
# 2201
# 2301
# 2401
# 2501
# 2601
# 2701
# 2801
# 2901
# 3001
# 3101
# 3201
# 3301
# 3401
# 3501
# 3601
# 3701
# 3801
# 3901
# 4001
# 4101
# 4201
# 4301
# 4401
# 4501
# 4601
# 4701
# 4801
# 4901
# 5001
# 5101
# 5201
# 5301
# 5401
# 5501
# 5601
# 5701
# 5801
# 5901
# 6001
# 6101
# 6201
# 6301
# 6401
# 6501
# 6601
# 6701
# 6801
# 6901
# 7001
# 7101
# 7201
# 7301
# 7401
# 7501
# 7601

# %%
# Creating a dataframe
ukcp_df = pd.DataFrame(therapist_data)

# %%
# Saving
ukcp_df.to_csv('ukcp_df.csv')

# %% [markdown]
# # Part 3: EDA
# ## Exploring the types of therapies that are listed

# %%
# # Reading in the data
# ukcp_df = pd.read_csv('ukcp_df.csv')
# ukcp_df.drop(columns='Unnamed: 0', inplace=True)

# %%
# Checking how many profile section columns I have
ukcp_df.columns
# Out:
# Index(['name', 'address', 'Types of Therapies Offered', 'I work with',
#        'What I can help with', 'My Approach', 'About Me', 'Special Interests'],
#       dtype='object')

# %%
# I am mostly interested in 'Types of Therapies Offered', but some profiles might not have that filled in.
ukcp_df['Types of Therapies Offered'].isna().sum()
# Out:
# 95

# %% [markdown]
# There are only 95 profiles missing the data I need. Most likely they will have it entered in another paragraph, such as 'My Approach' and 'About Me'. It means I might need to look for target data in different sections of the profile.

# %%
# Checking for duplicate accounts
ukcp_df['name'].str.strip().duplicated().sum()
# Out:
# 0

# %%
# Double-checking data types
ukcp_df.dtypes
# Out:
# name                          object
# address                       object
# Types of Therapies Offered    object
# I work with                   object
# What I can help with          object
# My Approach                   object
# About Me                      object
# Special Interests             object
# dtype: object

# %% [markdown]
# I will now separate "Types of Therapies Offered" from other columns and count the values.

# %%
# Creating a separate df
ukcp_types = ukcp_df[['name', 'Types of Therapies Offered']]

# %%
# Dropping null values
ukcp_types = ukcp_types.dropna(subset='Types of Therapies Offered')

# %%
# Checking
ukcp_types['Types of Therapies Offered'].isna().sum()
# Out:
# 0

# %%
# Creating a new column for each modality
types_matrix = ukcp_types['Types of Therapies Offered'].str.split(', ', expand=True).add_prefix('therapy').fillna('')
types_matrix
# Out:
#                                        therapy0  \
# 0                   Integrative Psychotherapist
# 1               Psychosynthesis Psychotherapist
# 2           Family and Systemic Psychotherapist
# 3           Family and Systemic Psychotherapist
# 4                 Transpersonal Psychotherapist
# ...                                         ...
# 7694                           Lacanian Analyst
# 7695  Analytical Psychologist - Jungian Analyst
# 7696        Family and Systemic Psychotherapist
# 7697                              Group Analyst
# 7698        Family and Systemic Psychotherapist
#
#                             therapy1  \
# 0
# 1
# 2                   Family Therapist
# 3                   Family Therapist
# 4
# ...                              ...
# 7694  Psychoanalytic Psychotherapist
# 7695
# 7696                Family Therapist
# 7697
# 7698                Family Therapist
#
#                                         therapy2                  therapy3  \
# 0
# 1
# 2     Systemic Family and Couple Psychotherapist  Systemic Psychotherapist
# 3     Systemic Family and Couple Psychotherapist  Systemic Psychotherapist
# 4
# ...                                          ...                       ...
# 7694
# 7695
# 7696  Systemic Family and Couple Psychotherapist  Systemic Psychotherapist
# 7697
# 7698  Systemic Family and Couple Psychotherapist  Systemic Psychotherapist
#
#      therapy4 therapy5 therapy6 therapy7
# 0
# 1
# 2
# 3
# 4
# ...       ...      ...      ...      ...
# 7694
# 7695
# 7696
# 7697
# 7698
#
# [7604 rows x 8 columns]

# %%
# Creating an empty dataframe that I will add data to
types_count = pd.DataFrame(columns = ['modality', 'count'])
types_count
# Out:
# Empty DataFrame
# Columns: [modality, count]
# Index: []

# %%
# Creating a temporary dataframe with value counts for each column and concatenating them all to one
for column in types_matrix:
    temp_df = pd.DataFrame(types_matrix[column].value_counts().reset_index())
    temp_df.columns = ['modality', 'count']
    types_count = pd.concat([types_count, temp_df], axis=0, ignore_index=True)

# %%
# Stripping white space
types_count['modality'] = types_count['modality'].apply(lambda x: x.strip())

# %%
# Aggregating count values from all columns
types_count = types_count.groupby('modality').sum()
types_count.drop(index = '', inplace=True) # dropping aggregated none-values
types_count = types_count.sort_values('count', ascending=False) # sorting

# %%
types_count
# Out:
#                                                 count
# modality
# Integrative Psychotherapist                      1345
# Family and Systemic Psychotherapist              1186
# Systemic Psychotherapist                         1185
# Family Therapist                                 1183
# Systemic Family and Couple Psychotherapist       1181
# ...                                               ...
# Psychosexual Psychotherapist                        1
# Child Counsellor                                    1
# Compassion based Psychotherapist                    1
# Constructivist Psychotherapist                      1
# Intercultural Psychoanalytical Psychotherapist      1
#
# [70 rows x 1 columns]

# %% [markdown]
# We have 70 different types of psychotherapy. It is very likely some are listed under different names and making the total number bigger than it actually is.

# %%
# Resetting index
types_count = types_count.reset_index()
types_count.columns = ['modality', 'count']
types_count
# Out:
#                                           modality  count
# 0                      Integrative Psychotherapist   1345
# 1              Family and Systemic Psychotherapist   1186
# 2                         Systemic Psychotherapist   1185
# 3                                 Family Therapist   1183
# 4       Systemic Family and Couple Psychotherapist   1181
# ..                                             ...    ...
# 65                    Psychosexual Psychotherapist      1
# 66                                Child Counsellor      1
# 67                Compassion based Psychotherapist      1
# 68                  Constructivist Psychotherapist      1
# 69  Intercultural Psychoanalytical Psychotherapist      1
#
# [70 rows x 2 columns]

# %%
# Prining all values so I can see them better, and sorting alphabetically
for count, row in enumerate(types_count['modality'].sort_values()):
    print(count, row)
# Out:
# 0 Adolescent Counsellor
# 1 Adolescent Psychotherapeutic Counsellor
# 2 Adolescent Psychotherapist
# 3 Analytical Psychologist
# 4 Analytical Psychologist - Jungian Analyst
# 5 Analytical Psychotherapist
# 6 Analytical Psychotherapist (Jungian)
# 7 Attachment-based Psychoanalytic Psychotherapist
# 8 Biodynamic Psychotherapist
# 9 Body Psychotherapist
# 10 Child Counsellor
# 11 Child Psychotherapeutic Counsellor
# 12 Child Psychotherapist
# 13 Child and Adolescent Psychotherapeutic Counsellor
# 14 Child and Adolescent Psychotherapist
# 15 Cognitive Analytic Therapist
# 16 Cognitive and Behavioural Psychotherapist
# 17 Compassion based Psychotherapist
# 18 Constructivist Psychotherapist
# 19 Contemporary Psychoanalyst
# 20 Contemporary Psychotherapist
# 21 Core Process Psychotherapist
# 22 Dance Movement Psychotherapist
# 23 Educational Psychotherapist
# 24 Existential Psychotherapist
# 25 Existential-Analytic Psychotherapist
# 26 Family Therapist
# 27 Family and Systemic Psychotherapist
# 28 Gestalt Group Psychotherapist
# 29 Gestalt Psychotherapeutic Counsellor
# 30 Gestalt Psychotherapist
# 31 Group Analyst
# 32 Group Analytic Psychotherapist
# 33 Humanistic Psychotherapeutic Counsellor
# 34 Humanistic Psychotherapist
# 35 Humanistic and Integrative Psychotherapist
# 36 Hypno -Psychotherapist
# 37 Integrative Arts Psychotherapist
# 38 Integrative Child Psychotherapist
# 39 Integrative Psychosynthesis Psychotherapist
# 40 Integrative Psychotherapeutic Counsellor
# 41 Integrative Psychotherapist
# 42 Integrative Transpersonal Psychotherapeutic Counsellor
# 43 Integrative Transpersonal Psychotherapist
# 44 Intercultural Psychoanalytical Psychotherapist
# 45 Intersubjective Psychotherapist
# 46 Jungian Analytical Psychotherapist
# 47 Lacanian Analyst
# 48 Medical Psychotherapist
# 49 Mindfulness Based Psychotherapist
# 50 Neuro-linguistic Psychotherapist
# 51 Outcome Oriented Psychotherapist
# 52 Parent Infant Psychoanalytic Psychotherapist
# 53 Person Centred Psychotherapist
# 54 Personal Construct Psychotherapist
# 55 Process Oriented Psychotherapist
# 56 Psychoanalyst
# 57 Psychoanalytic Psychotherapist
# 58 Psychodrama Psychotherapist
# 59 Psychodynamic Psychotherapist
# 60 Psychosexual Psychotherapist
# 61 Psychosynthesis Psychotherapeutic Counsellor
# 62 Psychosynthesis Psychotherapist
# 63 Psychotherapeutic Counsellor
# 64 Sexual and Relationship Psychotherapist
# 65 Systemic Family and Couple Psychotherapist
# 66 Systemic Psychotherapist
# 67 Transactional Analysis Psychotherapist
# 68 Transpersonal Psychotherapist
# 69 UTC Psychotherapist

# %% [markdown]
# It is clear that some therapies do indeed appear under multiple names, and are likely listed together. I will separate all listings of more than one therapy type and inspect them.

# %%
# Aggregating all variations of therapy listings
dup_types = pd.DataFrame(ukcp_types['Types of Therapies Offered'].value_counts())
dup_types = dup_types.reset_index()
dup_types.columns = ['types', 'count']

# %%
# Counting number of commas (separator between the types). It will tell me how many types of therapies are listed in each
# profile.
dup_types['comma_count'] = 0
for i in range(0,len(dup_types)):
    dup_types.iloc[i, 2] = dup_types.iloc[i, 0].count(', ')

# %%
dup_types['comma_count'].value_counts()
# Out:
# 1    142
# 2     69
# 0     63
# 4     12
# 3      7
# 5      2
# 7      1
# Name: comma_count, dtype: int64

# %% [markdown]
# The numbers are small enough that I can print all variations and inspect them.

# %%
for count, row in enumerate(dup_types['types']):
    print(count, row)
# Out:
# 0 Family and Systemic Psychotherapist, Family Therapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 1 Integrative Psychotherapist
# 2 Psychoanalytic Psychotherapist
# 3 Transpersonal Psychotherapist
# 4 Transactional Analysis Psychotherapist
# 5 Psychodynamic Psychotherapist
# 6 Psychotherapeutic Counsellor
# 7 Existential Psychotherapist
# 8 Gestalt Psychotherapist
# 9 Core Process Psychotherapist
# 10 Integrative Arts Psychotherapist
# 11 Group Analyst
# 12 Humanistic and Integrative Psychotherapist
# 13 Psychosynthesis Psychotherapist
# 14 Person Centred Psychotherapist
# 15 Attachment-based Psychoanalytic Psychotherapist
# 16 Hypno -Psychotherapist
# 17 Integrative Child Psychotherapist
# 18 Sexual and Relationship Psychotherapist
# 19 Analytical Psychologist - Jungian Analyst
# 20 Psychodrama Psychotherapist
# 21 Cognitive Analytic Therapist
# 22 Gestalt Group Psychotherapist, Gestalt Psychotherapist
# 23 Humanistic Psychotherapist
# 24 Child Psychotherapist, Integrative Child Psychotherapist
# 25 Adolescent Psychotherapist, Child Psychotherapist
# 26 Neuro-linguistic Psychotherapist
# 27 Group Analytic Psychotherapist
# 28 Integrative Psychosynthesis Psychotherapist
# 29 Body Psychotherapist, Integrative Psychotherapist
# 30 Biodynamic Psychotherapist
# 31 Child and Adolescent Psychotherapist
# 32 UTC Psychotherapist
# 33 Integrative Psychotherapist, Psychotherapeutic Counsellor
# 34 Educational Psychotherapist
# 35 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist
# 36 Dance Movement Psychotherapist
# 37 Child Psychotherapeutic Counsellor
# 38 Body Psychotherapist
# 39 Mindfulness Based Psychotherapist
# 40 Psychosynthesis Psychotherapeutic Counsellor
# 41 Integrative Transpersonal Psychotherapeutic Counsellor
# 42 Integrative Transpersonal Psychotherapist
# 43 Psychoanalytic Psychotherapist, Psychodynamic Psychotherapist
# 44 Child Psychotherapist
# 45 Humanistic Psychotherapist, Person Centred Psychotherapist
# 46 Process Oriented Psychotherapist
# 47 Child Psychotherapist, Integrative Psychotherapist
# 48 Medical Psychotherapist
# 49 Gestalt Psychotherapeutic Counsellor
# 50 Cognitive and Behavioural Psychotherapist
# 51 Humanistic Psychotherapeutic Counsellor
# 52 Integrative Psychotherapist, Psychodynamic Psychotherapist
# 53 Contemporary Psychotherapist, Hypno -Psychotherapist
# 54 Psychodynamic Psychotherapist, Psychotherapeutic Counsellor
# 55 Psychoanalyst
# 56 Existential-Analytic Psychotherapist
# 57 Jungian Analytical Psychotherapist
# 58 Existential Psychotherapist, Integrative Psychotherapist
# 59 Psychoanalyst, Psychoanalytic Psychotherapist
# 60 Humanistic Psychotherapist, Integrative Psychotherapist
# 61 Personal Construct Psychotherapist
# 62 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist (Jungian)
# 63 Attachment-based Psychoanalytic Psychotherapist, Psychoanalytic Psychotherapist
# 64 Child and Adolescent Psychotherapeutic Counsellor
# 65 Psychosynthesis Psychotherapist, Psychotherapeutic Counsellor
# 66 Contemporary Psychotherapist
# 67 Existential-Analytic Psychotherapist, Integrative Psychotherapist
# 68 Lacanian Analyst
# 69 Humanistic Psychotherapeutic Counsellor, Psychotherapeutic Counsellor
# 70 Contemporary Psychotherapist, Hypno -Psychotherapist, Outcome Oriented Psychotherapist
# 71 Analytical Psychologist - Jungian Analyst, Jungian Analytical Psychotherapist
# 72 Integrative Psychotherapeutic Counsellor
# 73 Child Psychotherapist, Transpersonal Psychotherapist
# 74 Integrative Psychotherapist, Transactional Analysis Psychotherapist
# 75 Group Analytic Psychotherapist, Psychoanalytic Psychotherapist
# 76 Parent Infant Psychoanalytic Psychotherapist
# 77 Child Psychotherapist, Transactional Analysis Psychotherapist
# 78 Child Psychotherapist, Integrative Arts Psychotherapist, Integrative Child Psychotherapist
# 79 Child Psychotherapist, Integrative Child Psychotherapist, Transpersonal Psychotherapist
# 80 Integrative Psychotherapist, Psychoanalytic Psychotherapist
# 81 Analytical Psychotherapist
# 82 Child and Adolescent Psychotherapist, Psychotherapeutic Counsellor
# 83 Intersubjective Psychotherapist, Psychotherapeutic Counsellor
# 84 Lacanian Analyst, Psychoanalytic Psychotherapist
# 85 Humanistic and Integrative Psychotherapist, Transpersonal Psychotherapist
# 86 Group Analyst, Psychoanalytic Psychotherapist
# 87 Analytical Psychotherapist (Jungian)
# 88 Existential Psychotherapist, Humanistic and Integrative Psychotherapist
# 89 Integrative Psychosynthesis Psychotherapist, Integrative Psychotherapist
# 90 Group Analyst, Group Analytic Psychotherapist
# 91 Child Psychotherapist, Integrative Arts Psychotherapist
# 92 Hypno -Psychotherapist, Integrative Psychotherapist
# 93 Group Analytic Psychotherapist, Psychodynamic Psychotherapist
# 94 Analytical Psychologist, Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist, Analytical Psychotherapist (Jungian)
# 95 Child and Adolescent Psychotherapist, Integrative Psychotherapist
# 96 Hypno -Psychotherapist, Neuro-linguistic Psychotherapist
# 97 Psychosynthesis Psychotherapeutic Counsellor, Psychosynthesis Psychotherapist
# 98 Sexual and Relationship Psychotherapist, Transpersonal Psychotherapist
# 99 Cognitive Analytic Therapist, Psychoanalytic Psychotherapist
# 100 Analytical Psychologist
# 101 Gestalt Psychotherapist, Humanistic Psychotherapist
# 102 Gestalt Psychotherapist, Humanistic and Integrative Psychotherapist
# 103 Intersubjective Psychotherapist
# 104 Attachment-based Psychoanalytic Psychotherapist, Integrative Psychotherapist
# 105 Child Psychotherapist, Psychoanalytic Psychotherapist
# 106 Analytical Psychologist - Jungian Analyst, Transpersonal Psychotherapist
# 107 Integrative Psychotherapist, Integrative Transpersonal Psychotherapist
# 108 Child and Adolescent Psychotherapeutic Counsellor, Integrative Psychotherapist
# 109 Child Psychotherapist, Integrative Child Psychotherapist, Integrative Psychotherapist
# 110 Contemporary Psychoanalyst, Psychoanalyst, Psychoanalytic Psychotherapist
# 111 Family and Systemic Psychotherapist
# 112 Integrative Psychotherapist, Neuro-linguistic Psychotherapist
# 113 Adolescent Psychotherapist, Child Psychotherapist, Integrative Psychotherapist
# 114 Integrative Child Psychotherapist, Transpersonal Psychotherapist
# 115 Gestalt Psychotherapist, Integrative Psychotherapist
# 116 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist (Jungian), Jungian Analytical Psychotherapist
# 117 Analytical Psychotherapist (Jungian), Jungian Analytical Psychotherapist
# 118 Analytical Psychologist - Jungian Analyst, Integrative Arts Psychotherapist
# 119 Core Process Psychotherapist, Humanistic and Integrative Psychotherapist
# 120 Humanistic and Integrative Psychotherapist, Psychodrama Psychotherapist
# 121 Body Psychotherapist, Humanistic Psychotherapist, Integrative Psychotherapist
# 122 Humanistic and Integrative Psychotherapist, Transactional Analysis Psychotherapist
# 123 Core Process Psychotherapist, Humanistic Psychotherapist
# 124 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist
# 125 Family and Systemic Psychotherapist, Family Therapist, Integrative Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 126 Child and Adolescent Psychotherapeutic Counsellor, Child and Adolescent Psychotherapist
# 127 Body Psychotherapist, Gestalt Psychotherapist, Humanistic Psychotherapist
# 128 Family and Systemic Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 129 Group Analyst, Psychodrama Psychotherapist
# 130 Core Process Psychotherapist, Mindfulness Based Psychotherapist
# 131 Humanistic Psychotherapist, Transactional Analysis Psychotherapist
# 132 Analytical Psychologist, Psychoanalytic Psychotherapist
# 133 Analytical Psychotherapist, Psychoanalytic Psychotherapist
# 134 Family and Systemic Psychotherapist, Family Therapist, Psychoanalytic Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 135 Integrative Psychosynthesis Psychotherapist, Psychosynthesis Psychotherapist
# 136 Child Psychotherapist, Process Oriented Psychotherapist
# 137 Existential Psychotherapist, Gestalt Psychotherapist
# 138 Analytical Psychologist - Jungian Analyst, Psychoanalytic Psychotherapist
# 139 Humanistic and Integrative Psychotherapist, Process Oriented Psychotherapist
# 140 Family and Systemic Psychotherapist, Family Therapist, Sexual and Relationship Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 141 Group Analyst, Psychodynamic Psychotherapist
# 142 Child Psychotherapist, Existential Psychotherapist
# 143 Integrative Psychotherapeutic Counsellor, Integrative Psychotherapist
# 144 Child Psychotherapist, Family and Systemic Psychotherapist, Family Therapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 145 Analytical Psychotherapist (Jungian), Group Analyst
# 146 Child Psychotherapist, Contemporary Psychotherapist, Hypno -Psychotherapist
# 147 Group Analytic Psychotherapist, Integrative Psychotherapist, Psychodrama Psychotherapist
# 148 Adolescent Psychotherapeutic Counsellor, Integrative Child Psychotherapist
# 149 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist, Transpersonal Psychotherapist
# 150 Existential Psychotherapist, Gestalt Group Psychotherapist, Psychotherapeutic Counsellor
# 151 Humanistic and Integrative Psychotherapist, Humanistic Psychotherapist, Integrative Psychosynthesis Psychotherapist, Integrative Psychotherapist, Psychosynthesis Psychotherapist, Psychotherapeutic Counsellor, Sexual and Relationship Psychotherapist, Transpersonal Psychotherapist
# 152 Analytical Psychotherapist, Jungian Analytical Psychotherapist
# 153 Group Analyst, Psychoanalytic Psychotherapist, Systemic Psychotherapist
# 154 Humanistic and Integrative Psychotherapist, Psychoanalytic Psychotherapist
# 155 Hypno -Psychotherapist, Psychotherapeutic Counsellor
# 156 Analytical Psychotherapist, Integrative Psychotherapist, Psychoanalytic Psychotherapist, Psychodynamic Psychotherapist, Psychotherapeutic Counsellor
# 157 Group Analyst, Transpersonal Psychotherapist
# 158 Core Process Psychotherapist, Existential Psychotherapist, Transpersonal Psychotherapist
# 159 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist, Person Centred Psychotherapist
# 160 Family and Systemic Psychotherapist, Family Therapist, Gestalt Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 161 Adolescent Psychotherapeutic Counsellor
# 162 Group Analyst, Sexual and Relationship Psychotherapist
# 163 Integrative Arts Psychotherapist, Transactional Analysis Psychotherapist
# 164 Jungian Analytical Psychotherapist, Psychodynamic Psychotherapist, Psychotherapeutic Counsellor
# 165 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist, Psychodynamic Psychotherapist
# 166 Analytical Psychotherapist, Humanistic and Integrative Psychotherapist, Integrative Psychotherapist
# 167 Psychosexual Psychotherapist
# 168 Child Psychotherapist, Family Therapist, Integrative Child Psychotherapist
# 169 Systemic Family and Couple Psychotherapist
# 170 Child Psychotherapeutic Counsellor, Integrative Arts Psychotherapist
# 171 Biodynamic Psychotherapist, Integrative Psychotherapist
# 172 Humanistic and Integrative Psychotherapist, Psychosynthesis Psychotherapist
# 173 Child Psychotherapeutic Counsellor, Group Analytic Psychotherapist
# 174 Family Therapist
# 175 Child Psychotherapist, Humanistic Psychotherapist
# 176 Integrative Psychosynthesis Psychotherapist, Transpersonal Psychotherapist
# 177 Existential-Analytic Psychotherapist, Psychotherapeutic Counsellor
# 178 Analytical Psychologist - Jungian Analyst, Psychotherapeutic Counsellor
# 179 Child Psychotherapist, Gestalt Psychotherapist
# 180 Analytical Psychologist, Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist, Analytical Psychotherapist (Jungian), Jungian Analytical Psychotherapist
# 181 Adolescent Psychotherapist, Attachment-based Psychoanalytic Psychotherapist, Child Psychotherapist
# 182 Gestalt Psychotherapist, Humanistic and Integrative Psychotherapist, Humanistic Psychotherapist, Integrative Psychotherapist, Psychotherapeutic Counsellor, Transactional Analysis Psychotherapist
# 183 Adolescent Psychotherapist, Integrative Child Psychotherapist
# 184 Child Psychotherapeutic Counsellor, Child Psychotherapist
# 185 Child and Adolescent Psychotherapist, Family and Systemic Psychotherapist, Family Therapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 186 Attachment-based Psychoanalytic Psychotherapist, Integrative Child Psychotherapist, Integrative Psychotherapist
# 187 Lacanian Analyst, Psychoanalyst, Psychoanalytic Psychotherapist
# 188 Educational Psychotherapist, Psychoanalytic Psychotherapist
# 189 Analytical Psychotherapist, Attachment-based Psychoanalytic Psychotherapist, Child Psychotherapist, Psychoanalytic Psychotherapist
# 190 Compassion based Psychotherapist, Personal Construct Psychotherapist
# 191 Humanistic Psychotherapist, Transpersonal Psychotherapist
# 192 Body Psychotherapist, Core Process Psychotherapist
# 193 Analytical Psychotherapist, Group Analytic Psychotherapist
# 194 Family and Systemic Psychotherapist, Family Therapist
# 195 Gestalt Group Psychotherapist, Gestalt Psychotherapist, Integrative Psychotherapist
# 196 Humanistic Psychotherapist, Psychotherapeutic Counsellor, Sexual and Relationship Psychotherapist
# 197 Psychodynamic Psychotherapist, Transpersonal Psychotherapist
# 198 Humanistic and Integrative Psychotherapist, Integrative Child Psychotherapist
# 199 Group Analyst, Integrative Psychotherapist
# 200 Existential Psychotherapist, Integrative Psychotherapeutic Counsellor, Integrative Psychotherapist
# 201 Attachment-based Psychoanalytic Psychotherapist, Integrative Child Psychotherapist
# 202 Child Psychotherapeutic Counsellor, Humanistic Psychotherapist, Person Centred Psychotherapist
# 203 Integrative Child Psychotherapist, Parent Infant Psychoanalytic Psychotherapist
# 204 Integrative Psychotherapist, Transactional Analysis Psychotherapist, Transpersonal Psychotherapist
# 205 Integrative Psychotherapist, Psychodynamic Psychotherapist, Psychotherapeutic Counsellor
# 206 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist, Psychodynamic Psychotherapist, Psychotherapeutic Counsellor
# 207 Analytical Psychologist - Jungian Analyst, Family and Systemic Psychotherapist
# 208 Intercultural Psychoanalytical Psychotherapist
# 209 Adolescent Psychotherapist, Child Psychotherapist, Psychodynamic Psychotherapist
# 210 Family and Systemic Psychotherapist, Psychoanalytic Psychotherapist
# 211 Humanistic and Integrative Psychotherapist, Humanistic Psychotherapist, Integrative Psychotherapist
# 212 Integrative Psychotherapist, Integrative Transpersonal Psychotherapist, Psychosynthesis Psychotherapist
# 213 Humanistic Psychotherapeutic Counsellor, Person Centred Psychotherapist
# 214 Group Analytic Psychotherapist, Transpersonal Psychotherapist
# 215 Analytical Psychotherapist, Integrative Psychotherapist, Psychoanalytic Psychotherapist
# 216 Integrative Psychosynthesis Psychotherapist, Psychosynthesis Psychotherapist, Transpersonal Psychotherapist
# 217 Core Process Psychotherapist, Group Analyst
# 218 Group Analytic Psychotherapist, Psychoanalytic Psychotherapist, Psychodynamic Psychotherapist
# 219 Psychoanalyst, Psychoanalytic Psychotherapist, Psychodynamic Psychotherapist
# 220 Attachment-based Psychoanalytic Psychotherapist, Psychoanalytic Psychotherapist, Transpersonal Psychotherapist
# 221 Integrative Arts Psychotherapist, Psychoanalytic Psychotherapist, Psychodynamic Psychotherapist
# 222 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist, Analytical Psychotherapist (Jungian)
# 223 Family and Systemic Psychotherapist, Family Therapist, Psychodynamic Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 224 Child Psychotherapist, Educational Psychotherapist
# 225 Humanistic Psychotherapist, Psychoanalytic Psychotherapist
# 226 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist, Psychoanalytic Psychotherapist
# 227 Family Therapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 228 Family and Systemic Psychotherapist, Family Therapist, Systemic Psychotherapist
# 229 Integrative Arts Psychotherapist, Jungian Analytical Psychotherapist
# 230 Child Psychotherapist, Gestalt Group Psychotherapist, Gestalt Psychotherapist
# 231 Existential-Analytic Psychotherapist, Psychoanalytic Psychotherapist
# 232 Psychoanalytic Psychotherapist, Transactional Analysis Psychotherapist
# 233 Integrative Psychotherapist, Psychosynthesis Psychotherapist, Transpersonal Psychotherapist
# 234 Integrative Psychotherapeutic Counsellor, Integrative Psychotherapist, Psychotherapeutic Counsellor
# 235 Body Psychotherapist, Gestalt Psychotherapist
# 236 Family and Systemic Psychotherapist, Family Therapist, Integrative Psychosynthesis Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 237 Humanistic Psychotherapist, Psychotherapeutic Counsellor
# 238 Integrative Psychosynthesis Psychotherapist, Integrative Transpersonal Psychotherapist
# 239 Child and Adolescent Psychotherapeutic Counsellor, Child and Adolescent Psychotherapist, Psychotherapeutic Counsellor
# 240 Biodynamic Psychotherapist, Gestalt Psychotherapist, Integrative Arts Psychotherapist
# 241 Existential Psychotherapist, Gestalt Group Psychotherapist
# 242 Humanistic and Integrative Psychotherapist, Humanistic Psychotherapeutic Counsellor
# 243 Humanistic and Integrative Psychotherapist, Humanistic Psychotherapist
# 244 Adolescent Counsellor, Family and Systemic Psychotherapist, Family Therapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 245 Child and Adolescent Psychotherapist, Child Psychotherapist, Integrative Child Psychotherapist
# 246 Child Psychotherapeutic Counsellor, Group Analyst
# 247 Existential Psychotherapist, Psychoanalytic Psychotherapist
# 248 Psychoanalytic Psychotherapist, Psychosynthesis Psychotherapist
# 249 Humanistic and Integrative Psychotherapist, Psychotherapeutic Counsellor, Transpersonal Psychotherapist
# 250 Humanistic Psychotherapist, Person Centred Psychotherapist, Psychotherapeutic Counsellor
# 251 Child Psychotherapist, Humanistic and Integrative Psychotherapist, Integrative Child Psychotherapist
# 252 Neuro-linguistic Psychotherapist, Systemic Psychotherapist
# 253 Analytical Psychologist, Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist, Jungian Analytical Psychotherapist
# 254 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist (Jungian), Jungian Analytical Psychotherapist, Psychoanalyst, Psychoanalytic Psychotherapist
# 255 Biodynamic Psychotherapist, Body Psychotherapist, Integrative Psychotherapist
# 256 Constructivist Psychotherapist
# 257 Adolescent Counsellor, Child Counsellor
# 258 Analytical Psychotherapist, Attachment-based Psychoanalytic Psychotherapist, Group Analytic Psychotherapist
# 259 Integrative Psychotherapist, Process Oriented Psychotherapist
# 260 Existential Psychotherapist, Psychoanalyst, Psychoanalytic Psychotherapist
# 261 Gestalt Psychotherapist, Systemic Psychotherapist
# 262 Core Process Psychotherapist, Humanistic and Integrative Psychotherapist, Psychoanalytic Psychotherapist
# 263 Psychoanalytic Psychotherapist, Psychotherapeutic Counsellor
# 264 Child Psychotherapist, Family and Systemic Psychotherapist, Family Therapist, Integrative Child Psychotherapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 265 Lacanian Analyst, Psychoanalyst
# 266 Integrative Arts Psychotherapist, Integrative Psychotherapist
# 267 Analytical Psychologist - Jungian Analyst, Integrative Psychotherapist
# 268 Psychodynamic Psychotherapist, Sexual and Relationship Psychotherapist
# 269 Outcome Oriented Psychotherapist
# 270 Child Psychotherapist, Humanistic and Integrative Psychotherapist, Integrative Psychotherapist
# 271 Contemporary Psychotherapist, Integrative Psychotherapist, Neuro-linguistic Psychotherapist
# 272 Group Analyst, Group Analytic Psychotherapist, Psychoanalytic Psychotherapist
# 273 Analytical Psychologist, Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist
# 274 Medical Psychotherapist, Psychoanalytic Psychotherapist
# 275 Humanistic and Integrative Psychotherapist, Hypno -Psychotherapist, Transpersonal Psychotherapist
# 276 Analytical Psychotherapist, Attachment-based Psychoanalytic Psychotherapist, Integrative Psychotherapist
# 277 Adolescent Psychotherapist, Child Psychotherapist, Core Process Psychotherapist
# 278 Existential-Analytic Psychotherapist, Integrative Psychotherapist, Psychotherapeutic Counsellor
# 279 Humanistic and Integrative Psychotherapist, Hypno -Psychotherapist, Sexual and Relationship Psychotherapist
# 280 Integrative Arts Psychotherapist, Integrative Child Psychotherapist
# 281 Group Analyst, Group Analytic Psychotherapist, Psychodynamic Psychotherapist
# 282 Body Psychotherapist, Gestalt Group Psychotherapist, Gestalt Psychotherapist, Integrative Psychotherapist
# 283 Psychosynthesis Psychotherapeutic Counsellor, Psychotherapeutic Counsellor
# 284 Neuro-linguistic Psychotherapist, Sexual and Relationship Psychotherapist
# 285 Gestalt Psychotherapist, Intersubjective Psychotherapist, Psychotherapeutic Counsellor
# 286 Humanistic and Integrative Psychotherapist, Integrative Arts Psychotherapist
# 287 Existential Psychotherapist, Humanistic and Integrative Psychotherapist, Integrative Psychotherapist
# 288 Attachment-based Psychoanalytic Psychotherapist, Parent Infant Psychoanalytic Psychotherapist
# 289 Body Psychotherapist, Humanistic Psychotherapist
# 290 Family Therapist, Systemic Psychotherapist
# 291 Gestalt Psychotherapist, Person Centred Psychotherapist
# 292 Existential Psychotherapist, Psychotherapeutic Counsellor
# 293 Gestalt Group Psychotherapist, Gestalt Psychotherapist, Humanistic and Integrative Psychotherapist, Integrative Psychotherapist
# 294 Child Psychotherapist, Integrative Psychotherapist, Psychotherapeutic Counsellor
# 295 Humanistic Psychotherapist, Integrative Arts Psychotherapist

# %%
dup_types
# Out:
#                                                  types  count  comma_count
# 0    Family and Systemic Psychotherapist, Family Th...   1163            3
# 1                          Integrative Psychotherapist   1126            0
# 2                       Psychoanalytic Psychotherapist    551            0
# 3                        Transpersonal Psychotherapist    411            0
# 4               Transactional Analysis Psychotherapist    379            0
# ..                                                 ...    ...          ...
# 291  Gestalt Psychotherapist, Person Centred Psycho...      1            1
# 292  Existential Psychotherapist, Psychotherapeutic...      1            1
# 293  Gestalt Group Psychotherapist, Gestalt Psychot...      1            3
# 294  Child Psychotherapist, Integrative Psychothera...      1            2
# 295  Humanistic Psychotherapist, Integrative Arts P...      1            1
#
# [296 rows x 3 columns]

# %% [markdown]
# I also want to see most common variations - those that appear more than once, and have more than one therapy listed.

# %%
filt = (dup_types['count']>1) & dup_types['comma_count']>0
dup_type_groups = dup_types[filt]

# %%
# Printing variations that appear more than once
for count, row in enumerate(dup_type_groups['types']):
    print(count, row)
# Out:
# 0 Family and Systemic Psychotherapist, Family Therapist, Systemic Family and Couple Psychotherapist, Systemic Psychotherapist
# 1 Gestalt Group Psychotherapist, Gestalt Psychotherapist
# 2 Child Psychotherapist, Integrative Child Psychotherapist
# 3 Adolescent Psychotherapist, Child Psychotherapist
# 4 Body Psychotherapist, Integrative Psychotherapist
# 5 Integrative Psychotherapist, Psychotherapeutic Counsellor
# 6 Humanistic and Integrative Psychotherapist, Integrative Psychotherapist
# 7 Psychoanalytic Psychotherapist, Psychodynamic Psychotherapist
# 8 Humanistic Psychotherapist, Person Centred Psychotherapist
# 9 Child Psychotherapist, Integrative Psychotherapist
# 10 Integrative Psychotherapist, Psychodynamic Psychotherapist
# 11 Contemporary Psychotherapist, Hypno -Psychotherapist
# 12 Psychodynamic Psychotherapist, Psychotherapeutic Counsellor
# 13 Existential Psychotherapist, Integrative Psychotherapist
# 14 Psychoanalyst, Psychoanalytic Psychotherapist
# 15 Humanistic Psychotherapist, Integrative Psychotherapist
# 16 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist (Jungian)
# 17 Attachment-based Psychoanalytic Psychotherapist, Psychoanalytic Psychotherapist
# 18 Psychosynthesis Psychotherapist, Psychotherapeutic Counsellor
# 19 Existential-Analytic Psychotherapist, Integrative Psychotherapist
# 20 Humanistic Psychotherapeutic Counsellor, Psychotherapeutic Counsellor
# 21 Analytical Psychologist - Jungian Analyst, Jungian Analytical Psychotherapist
# 22 Child Psychotherapist, Transpersonal Psychotherapist
# 23 Integrative Psychotherapist, Transactional Analysis Psychotherapist
# 24 Group Analytic Psychotherapist, Psychoanalytic Psychotherapist
# 25 Child Psychotherapist, Transactional Analysis Psychotherapist
# 26 Integrative Psychotherapist, Psychoanalytic Psychotherapist
# 27 Child and Adolescent Psychotherapist, Psychotherapeutic Counsellor
# 28 Intersubjective Psychotherapist, Psychotherapeutic Counsellor
# 29 Lacanian Analyst, Psychoanalytic Psychotherapist
# 30 Humanistic and Integrative Psychotherapist, Transpersonal Psychotherapist
# 31 Group Analyst, Psychoanalytic Psychotherapist
# 32 Existential Psychotherapist, Humanistic and Integrative Psychotherapist
# 33 Integrative Psychosynthesis Psychotherapist, Integrative Psychotherapist
# 34 Group Analyst, Group Analytic Psychotherapist
# 35 Child Psychotherapist, Integrative Arts Psychotherapist
# 36 Hypno -Psychotherapist, Integrative Psychotherapist
# 37 Group Analytic Psychotherapist, Psychodynamic Psychotherapist
# 38 Analytical Psychologist, Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist, Analytical Psychotherapist (Jungian)
# 39 Child and Adolescent Psychotherapist, Integrative Psychotherapist
# 40 Hypno -Psychotherapist, Neuro-linguistic Psychotherapist
# 41 Psychosynthesis Psychotherapeutic Counsellor, Psychosynthesis Psychotherapist
# 42 Sexual and Relationship Psychotherapist, Transpersonal Psychotherapist
# 43 Cognitive Analytic Therapist, Psychoanalytic Psychotherapist
# 44 Gestalt Psychotherapist, Humanistic Psychotherapist
# 45 Gestalt Psychotherapist, Humanistic and Integrative Psychotherapist
# 46 Attachment-based Psychoanalytic Psychotherapist, Integrative Psychotherapist
# 47 Child Psychotherapist, Psychoanalytic Psychotherapist
# 48 Analytical Psychologist - Jungian Analyst, Transpersonal Psychotherapist
# 49 Integrative Psychotherapist, Integrative Transpersonal Psychotherapist
# 50 Child and Adolescent Psychotherapeutic Counsellor, Integrative Psychotherapist
# 51 Integrative Psychotherapist, Neuro-linguistic Psychotherapist
# 52 Integrative Child Psychotherapist, Transpersonal Psychotherapist
# 53 Gestalt Psychotherapist, Integrative Psychotherapist
# 54 Analytical Psychotherapist (Jungian), Jungian Analytical Psychotherapist
# 55 Analytical Psychologist - Jungian Analyst, Integrative Arts Psychotherapist
# 56 Core Process Psychotherapist, Humanistic and Integrative Psychotherapist
# 57 Humanistic and Integrative Psychotherapist, Psychodrama Psychotherapist
# 58 Humanistic and Integrative Psychotherapist, Transactional Analysis Psychotherapist
# 59 Core Process Psychotherapist, Humanistic Psychotherapist
# 60 Analytical Psychologist - Jungian Analyst, Analytical Psychotherapist
# 61 Child and Adolescent Psychotherapeutic Counsellor, Child and Adolescent Psychotherapist
# 62 Group Analyst, Psychodrama Psychotherapist
# 63 Core Process Psychotherapist, Mindfulness Based Psychotherapist
# 64 Humanistic Psychotherapist, Transactional Analysis Psychotherapist
# 65 Analytical Psychologist, Psychoanalytic Psychotherapist
# 66 Analytical Psychotherapist, Psychoanalytic Psychotherapist
# 67 Integrative Psychosynthesis Psychotherapist, Psychosynthesis Psychotherapist
# 68 Child Psychotherapist, Process Oriented Psychotherapist
# 69 Existential Psychotherapist, Gestalt Psychotherapist
# 70 Analytical Psychologist - Jungian Analyst, Psychoanalytic Psychotherapist
# 71 Humanistic and Integrative Psychotherapist, Process Oriented Psychotherapist
# 72 Group Analyst, Psychodynamic Psychotherapist
# 73 Child Psychotherapist, Existential Psychotherapist
# 74 Integrative Psychotherapeutic Counsellor, Integrative Psychotherapist

# %% [markdown]
# # Conclusion:
# - Most profiles have "Types of Therapies Offered" listed in a separate section, but it may also be specified in other parts of the profile, such as "About Me" or "My Approach". For an accurate count, I might need to search for listings in multiple profile sections.
# - I can reduce number of therapies by:
#     i) making the names consistent throughout
#     ii) ignoring the subtle differences between 'psychotherapist', 'counsellor', and 'psychotheraputic counsellor'
# - I need to be careful with umbrella terms such as Humanistic therapy, which can be either listed by itself or together with more specific types like Gestalt.
# - After reducing the number of therapies, I will know what to look for in other sections of the profiles, in case therapies are specified there instead.
